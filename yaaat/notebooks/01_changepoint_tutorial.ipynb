# %% [markdown]
# ### Introductory tutorial for Changepoint Annotator
# ---
# ---

# %% [markdown]
# Load GUI

# %%
import yaaat
from yaaat.changepoint_annotator import ChangepointAnnotator
import tkinter as tk

root = tk.Tk()
app = ChangepointAnnotator(root)

root.geometry("1400x800")
root.mainloop()
# Out:
# Auto-loading last directory: D:\miniconda3\Lib\site-packages\yaaat\test_files\test_audio\syllables\kiwi
# Loading slice_1.wav...
# DEBUG: Before clearing - annotations: 0, syllables: 0
# DEBUG: After clearing - annotations: 0, syllables: 0
# update_display called: recompute_spec=True
# DEBUG: Plotting 0 annotations
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\miniconda3\envs\fruits\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "d:\miniconda3\envs\fruits\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "d:\miniconda3\envs\fruits\Lib\site-packages\yaaat\changepoint_annotator.py", line 2390, in auto_load_directory
#     self.load_current_file()
#   File "d:\miniconda3\envs\fruits\Lib\site-packages\yaaat\changepoint_annotator.py", line 2429, in load_current_file
#     label_file = self.label_dir / f"{audio_file.stem}_changepoint_annotations.json"
# ...

# %% [markdown]
# ### Use API to add annotation coordinates
# ---
